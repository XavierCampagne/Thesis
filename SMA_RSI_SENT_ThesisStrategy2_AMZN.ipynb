# %% [markdown]
# # Code for the model testing

# %%
#### Importation of libraries ####

from datetime import datetime
from datetime import date
from pandas_datareader.data import DataReader
from yahoofinancials import YahooFinancials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import backtrader as bt
import talib
pd.options.mode.chained_assignment = None
import ipympl

# %% [markdown]
# # Trading strat and backtesting

# %%
#### Download of the csv created with all Sentiment and Financial Data ####

SENT = pd.read_csv('AMZN.csv', index_col=0)
SENT = SENT['2021-02-01':'2021-11-01']
SENT.head()
# Out:
#                    high          low         open        close   volume  \
# 2021-02-01  3350.260010  3235.030029  3242.360107  3342.879883  4160200
# 2021-02-02  3427.739990  3361.129883  3380.000000  3380.000000  7098600
# 2021-02-09  3338.000000  3297.840088  3312.489990  3305.000000  2203500
# 2021-02-10  3317.949951  3254.000000  3314.000000  3286.580078  3151600
# 2021-02-11  3292.000000  3248.060059  3292.000000  3262.129883  2301400
#
#                  neg       neu       pos  compound  references
# 2021-02-01  0.037686  0.820457  0.141829  0.141300          35
# 2021-02-02  0.000000  0.683000  0.317000  0.236950           2
# 2021-02-09  0.000000  1.000000  0.000000  0.000000           2
# 2021-02-10  0.044385  0.834077  0.121500  0.094827          26
# 2021-02-11  0.033654  0.849808  0.116500  0.094746          26

# %%
#### Declaration of References as a Backtrader indicator ####

from backtrader.indicators import Indicator
class Sentiment(bt.Indicator):
    lines = ('sentiment',)
    
    plotinfo = dict(plot=True,
                    subplot=True,
                    plotname='',
               )   
    
    def next(self):
        self.date = self.datas[0].datetime.date(0)
        self.sentiment = SENT['compound'].loc[self.date.strftime('%Y-%m-%d')]
        self.lines.sentiment[0] = SENT['compound'].loc[self.date.strftime('%Y-%m-%d')]

print(type(Sentiment))
# Out:
# <class 'backtrader.indicator.MetaIndicator'>

# %%
#### Declaration of References as a Backtrader indicator ####

from backtrader.indicators import Indicator
class References(bt.Indicator):
    lines = ('references',)
    
    plotinfo = dict(plot=True,
                    subplot=True,
                    plotname='',
               )   
    
    def next(self):
        self.date = self.datas[0].datetime.date(0)
        self.references = SENT['references'].loc[self.date.strftime('%Y-%m-%d')]
        self.lines.references[0] = SENT['references'].loc[self.date.strftime('%Y-%m-%d')]

print(type(References))
# Out:
# <class 'backtrader.indicator.MetaIndicator'>

# %%
################ STRATEGY BACKTESTING ################

class ThesisStrategy(bt.Strategy):
    
    #### Constant variables #####
    params = (
    ('short_period',12),    
    ('long_period',26),    
    ('sma_period',20),
    ('flag',False)
    )
    
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt, txt))
        
        
    
    def __init__(self):
        
        #### Data collection from the feed ####
        self.dataclose = self.datas[0].close
        self.date = self.datas[0].datetime.date(0)
        self.sentiment = Sentiment(self.data).sentiment
        self.references = References(self.data).references
        
        #### Declaration of transaction variables ####
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
        #### Definition of indicators #####
           
        self.SMA = bt.ind.SMA(period=self.params.short_period)
        self.RSI = bt.ind.RSI()
  
        
        
    ##### Trade notification #####
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Trade is done
            return

        #### Check for transaction and print the details ####
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
                self.bar_executed = len(self)

        
        self.order = None

        
    def notify_trade(self, trade):
        #### Print the results of the transaction (Profit and loss) #### 
        if not trade.isclosed:
            return
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    

    def next(self):
        #### Daily notification about relevant data ####
        self.log('Close, %.2f$, Sentiment %.3f, Daily References %.0f' % (self.dataclose[-1], self.sentiment[0], self.references[0]))
        #### Check for orders proceeding ####
        if self.order:
            return
        
        #### Strategy 2, SMA RSI and News ####
        
        if not self.position and not self.params.flag: 
            if self.dataclose[0] > self.SMA and not self.position and not self.RSI > 70:
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.order = self.buy()
                
        if ((self.dataclose[0] < self.SMA or self.RSI > 70 or self.references > 30 or self.sentiment > 0.3) and self.position):
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.params.flag = True
                self.order = self.sell()
                
        if not (self.dataclose[0] < self.SMA or self.RSI > 70 or self.references > 30 or self.sentiment > 0.3):
                self.params.flag = False
                    
            
if __name__ == '__main__':
    cerebro = bt.Cerebro()
    
    #### Loading of the strategy in cerebro ####
    cerebro.addstrategy(ThesisStrategy)
    
    #### Datafeed ####
    data = bt.feeds.GenericCSVData(dataname='AMZN.csv',
                                  fromdate=datetime(2021,2,1),
                                  todate=datetime(2021,11,1),
                                  nullvalue=0.0,
                                  dtformat=('%Y-%m-%d'),
                                  datetime=0,
                                  high=1,
                                  low=2,
                                  open=3,
                                  close=4,
                                  volume=5,
                                  sentiment=6,
                                  references = 7,
                                  openinterest=-1
                                )
    cerebro.adddata(data)
    
    #### Creation of the portfolio and add of comissions ####
    cerebro.broker.setcash(100000)
    cerebro.broker.setcommission(commission=0.001, margin = 0)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    #### Run the backtesting #### 
    backtest = cerebro.run()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    #### Plot ####
    plt.rcParams['figure.figsize'] = [25, 15]
    plt.rcParams.update({'font.size': 12}) 
    # %matplotlib inline
    Backtest_results = cerebro.plot(volume=False)
    plt.savefig('SMA_RSI_SENT_Strategy_2_AMAZON_results.png')
# Out:
# Starting Portfolio Value: 100000.00
# 2021-02-26, Close, 3057.16$, Sentiment 0.169, Daily References 28
# 2021-03-01, Close, 3092.93$, Sentiment 0.057, Daily References 33
# 2021-03-02, Close, 3146.14$, Sentiment 0.100, Daily References 10
# 2021-03-04, Close, 3094.53$, Sentiment 0.166, Daily References 19
# 2021-03-05, Close, 2977.57$, Sentiment 0.101, Daily References 32
# 2021-03-08, Close, 3000.46$, Sentiment 0.186, Daily References 28
# 2021-03-09, Close, 2951.95$, Sentiment 0.220, Daily References 3
# 2021-03-11, Close, 3062.85$, Sentiment 0.096, Daily References 5
# 2021-03-11, BUY CREATE, 3113.59
# 2021-03-12, BUY EXECUTED, Price: 3075.00, Cost: 3075.00, Comm 3.08
# 2021-03-12, Close, 3113.59$, Sentiment 0.282, Daily References 31
# 2021-03-12, SELL CREATE, 3089.49
# 2021-03-15, SELL EXECUTED, Price: 3074.57, Cost: 3075.00, Comm 3.07
# 2021-03-15, OPERATION PROFIT, GROSS -0.43, NET -6.58
# 2021-03-15, Close, 3089.49$, Sentiment 0.071, Daily References 24
# 2021-03-16, Close, 3081.68$, Sentiment 0.151, Daily References 14
# 2021-03-16, BUY CREATE, 3091.86
# 2021-03-18, BUY EXECUTED, Price: 3101.00, Cost: 3101.00, Comm 3.10
# 2021-03-18, Close, 3091.86$, Sentiment 0.202, Daily References 11
# 2021-03-18, SELL CREATE, 3027.99
# 2021-03-19, SELL EXECUTED, Price: 3029.23, Cost: 3101.00, Comm 3.03
# 2021-03-19, OPERATION PROFIT, GROSS -71.77, NET -77.90
# 2021-03-19, Close, 3027.99$, Sentiment 0.214, Daily References 24
# 2021-03-22, Close, 3074.96$, Sentiment 0.189, Daily References 30
# 2021-03-22, BUY CREATE, 3110.87
# 2021-03-23, BUY EXECUTED, Price: 3127.00, Cost: 3127.00, Comm 3.13
# 2021-03-23, Close, 3110.87$, Sentiment 0.003, Daily References 13
# 2021-03-25, Close, 3137.50$, Sentiment 0.147, Daily References 9
# 2021-03-25, SELL CREATE, 3046.26
# 2021-03-26, SELL EXECUTED, Price: 3044.06, Cost: 3127.00, Comm 3.04
# 2021-03-26, OPERATION PROFIT, GROSS -82.94, NET -89.11
# 2021-03-26, Close, 3046.26$, Sentiment 0.098, Daily References 21
# 2021-03-29, Close, 3052.03$, Sentiment 0.148, Daily References 27
# 2021-03-30, Close, 3075.73$, Sentiment 0.098, Daily References 16
# 2021-04-07, Close, 3055.29$, Sentiment 0.175, Daily References 7
# 2021-04-08, Close, 3279.39$, Sentiment 0.136, Daily References 38
# 2021-04-08, BUY CREATE, 3299.30
# 2021-04-09, BUY EXECUTED, Price: 3304.70, Cost: 3304.70, Comm 3.30
# 2021-04-09, Close, 3299.30$, Sentiment 0.076, Daily References 42
# 2021-04-09, SELL CREATE, 3372.20
# 2021-04-14, SELL EXECUTED, Price: 3404.04, Cost: 3304.70, Comm 3.40
# 2021-04-14, OPERATION PROFIT, GROSS 99.34, NET 92.63
# 2021-04-14, Close, 3372.20$, Sentiment 0.091, Daily References 9
# 2021-04-15, Close, 3333.00$, Sentiment 0.155, Daily References 45
# 2021-04-15, BUY CREATE, 3379.09
# 2021-04-16, BUY EXECUTED, Price: 3380.00, Cost: 3380.00, Comm 3.38
# 2021-04-16, Close, 3379.09$, Sentiment 0.263, Daily References 22
# 2021-04-21, Close, 3399.44$, Sentiment 0.157, Daily References 26
# 2021-04-22, Close, 3362.02$, Sentiment 0.143, Daily References 23
# 2021-04-23, Close, 3309.04$, Sentiment -0.024, Daily References 18
# 2021-04-26, Close, 3340.88$, Sentiment 0.211, Daily References 13
# 2021-04-29, Close, 3409.00$, Sentiment 0.277, Daily References 17
# 2021-04-30, Close, 3471.31$, Sentiment 0.202, Daily References 43
# 2021-04-30, SELL CREATE, 3467.42
# 2021-05-03, SELL EXECUTED, Price: 3484.73, Cost: 3380.00, Comm 3.48
# 2021-05-03, OPERATION PROFIT, GROSS 104.73, NET 97.87
# 2021-05-03, Close, 3467.42$, Sentiment 0.079, Daily References 32
# 2021-05-04, Close, 3386.49$, Sentiment 0.150, Daily References 10
# 2021-05-05, Close, 3311.87$, Sentiment 0.059, Daily References 3
# 2021-05-06, Close, 3270.54$, Sentiment 0.123, Daily References 24
# 2021-05-07, Close, 3306.37$, Sentiment 0.123, Daily References 27
# 2021-05-10, Close, 3291.61$, Sentiment 0.078, Daily References 23
# 2021-05-11, Close, 3190.49$, Sentiment 0.020, Daily References 6
# 2021-05-13, Close, 3223.91$, Sentiment 0.172, Daily References 12
# 2021-05-14, Close, 3161.47$, Sentiment 0.118, Daily References 26
# 2021-05-17, Close, 3222.90$, Sentiment 0.210, Daily References 34
# 2021-05-18, Close, 3270.39$, Sentiment 0.062, Daily References 17
# 2021-05-26, Close, 3232.28$, Sentiment 0.193, Daily References 33
# 2021-05-27, Close, 3265.16$, Sentiment 0.169, Daily References 27
# 2021-05-28, Close, 3230.11$, Sentiment 0.146, Daily References 19
# 2021-06-02, Close, 3223.07$, Sentiment 0.259, Daily References 25
# 2021-06-03, Close, 3233.99$, Sentiment 0.254, Daily References 21
# 2021-06-04, Close, 3187.01$, Sentiment 0.014, Daily References 32
# 2021-06-07, Close, 3206.22$, Sentiment 0.092, Daily References 35
# 2021-06-10, Close, 3198.01$, Sentiment 0.167, Daily References 15
# 2021-06-11, Close, 3349.65$, Sentiment 0.241, Daily References 38
# 2021-06-11, BUY CREATE, 3346.83
# 2021-06-14, BUY EXECUTED, Price: 3346.83, Cost: 3346.83, Comm 3.35
# 2021-06-14, Close, 3346.83$, Sentiment 0.097, Daily References 28
# 2021-06-15, Close, 3383.87$, Sentiment 0.091, Daily References 35
# 2021-06-15, SELL CREATE, 3383.13
# 2021-06-21, SELL EXECUTED, Price: 3476.42, Cost: 3346.83, Comm 3.48
# 2021-06-21, OPERATION PROFIT, GROSS 129.59, NET 122.77
# 2021-06-21, Close, 3383.13$, Sentiment 0.198, Daily References 48
# 2021-06-22, Close, 3453.96$, Sentiment 0.167, Daily References 45
# 2021-06-24, Close, 3505.44$, Sentiment 0.197, Daily References 5
# 2021-06-25, Close, 3449.08$, Sentiment 0.156, Daily References 23
# 2021-06-25, BUY CREATE, 3401.46
# 2021-06-28, BUY EXECUTED, Price: 3416.00, Cost: 3416.00, Comm 3.42
# 2021-06-28, Close, 3401.46$, Sentiment 0.129, Daily References 22
# 2021-06-29, Close, 3443.89$, Sentiment 0.260, Daily References 25
# 2021-06-30, Close, 3448.14$, Sentiment 0.178, Daily References 1
# 2021-07-02, Close, 3440.16$, Sentiment 0.154, Daily References 22
# 2021-07-06, Close, 3510.98$, Sentiment 0.103, Daily References 48
# 2021-07-06, SELL CREATE, 3675.74
# 2021-07-09, SELL EXECUTED, Price: 3722.52, Cost: 3416.00, Comm 3.72
# 2021-07-09, OPERATION PROFIT, GROSS 306.52, NET 299.38
# 2021-07-09, Close, 3675.74$, Sentiment 0.205, Daily References 24
# 2021-07-12, Close, 3719.34$, Sentiment 0.111, Daily References 31
# 2021-07-13, Close, 3718.55$, Sentiment 0.204, Daily References 27
# 2021-07-14, Close, 3677.36$, Sentiment 0.156, Daily References 31
# 2021-07-14, BUY CREATE, 3681.68
# 2021-07-26, BUY EXECUTED, Price: 3673.17, Cost: 3673.17, Comm 3.67
# 2021-07-26, Close, 3681.68$, Sentiment 0.098, Daily References 26
# 2021-07-26, SELL CREATE, 3699.82
# 2021-07-27, SELL EXECUTED, Price: 3698.50, Cost: 3673.17, Comm 3.70
# 2021-07-27, OPERATION PROFIT, GROSS 25.33, NET 17.96
# 2021-07-27, Close, 3699.82$, Sentiment 0.142, Daily References 41
# 2021-07-28, Close, 3626.39$, Sentiment 0.219, Daily References 25
# 2021-07-29, Close, 3630.32$, Sentiment 0.056, Daily References 40
# 2021-07-30, Close, 3599.92$, Sentiment 0.340, Daily References 1
# 2021-08-02, Close, 3327.59$, Sentiment 0.106, Daily References 19
# 2021-08-03, Close, 3331.48$, Sentiment 0.163, Daily References 19
# 2021-08-04, Close, 3366.24$, Sentiment 0.092, Daily References 25
# 2021-08-05, Close, 3354.72$, Sentiment 0.084, Daily References 20
# 2021-08-06, Close, 3375.99$, Sentiment 0.168, Daily References 23
# 2021-08-09, Close, 3344.94$, Sentiment 0.179, Daily References 23
# 2021-08-10, Close, 3341.87$, Sentiment 0.181, Daily References 19
# 2021-08-11, Close, 3320.68$, Sentiment 0.084, Daily References 20
# 2021-08-12, Close, 3292.11$, Sentiment 0.216, Daily References 25
# 2021-08-13, Close, 3303.50$, Sentiment 0.160, Daily References 21
# 2021-08-16, Close, 3293.97$, Sentiment 0.115, Daily References 18
# 2021-08-17, Close, 3298.99$, Sentiment 0.121, Daily References 18
# 2021-08-18, Close, 3241.96$, Sentiment 0.116, Daily References 18
# 2021-08-19, Close, 3201.22$, Sentiment 0.226, Daily References 34
# 2021-08-20, Close, 3187.75$, Sentiment 0.104, Daily References 18
# 2021-08-23, Close, 3199.95$, Sentiment 0.236, Daily References 14
# 2021-08-24, Close, 3265.87$, Sentiment 0.074, Daily References 17
# 2021-08-24, BUY CREATE, 3305.78
# 2021-08-25, BUY EXECUTED, Price: 3309.87, Cost: 3309.87, Comm 3.31
# 2021-08-25, Close, 3305.78$, Sentiment 0.136, Daily References 28
# 2021-08-26, Close, 3299.18$, Sentiment 0.168, Daily References 14
# 2021-08-27, Close, 3316.00$, Sentiment 0.240, Daily References 7
# 2021-08-31, Close, 3349.63$, Sentiment 0.069, Daily References 14
# 2021-09-01, Close, 3470.79$, Sentiment 0.095, Daily References 42
# 2021-09-01, SELL CREATE, 3479.00
# 2021-09-02, SELL EXECUTED, Price: 3494.76, Cost: 3309.87, Comm 3.49
# 2021-09-02, OPERATION PROFIT, GROSS 184.89, NET 178.09
# 2021-09-02, Close, 3479.00$, Sentiment 0.047, Daily References 27
# 2021-09-03, Close, 3463.12$, Sentiment 0.167, Daily References 14
# 2021-09-03, BUY CREATE, 3478.05
# 2021-09-07, BUY EXECUTED, Price: 3478.00, Cost: 3478.00, Comm 3.48
# 2021-09-07, Close, 3478.05$, Sentiment 0.414, Daily References 12
# 2021-09-07, SELL CREATE, 3509.29
# 2021-09-08, SELL EXECUTED, Price: 3511.65, Cost: 3478.00, Comm 3.51
# 2021-09-08, OPERATION PROFIT, GROSS 33.65, NET 26.66
# 2021-09-08, Close, 3509.29$, Sentiment 0.014, Daily References 27
# 2021-09-09, Close, 3525.50$, Sentiment 0.225, Daily References 37
# 2021-09-09, BUY CREATE, 3484.16
# 2021-09-10, BUY EXECUTED, Price: 3501.83, Cost: 3501.83, Comm 3.50
# 2021-09-10, Close, 3484.16$, Sentiment 0.154, Daily References 20
# 2021-09-15, Close, 3469.15$, Sentiment 0.085, Daily References 24
# 2021-09-16, Close, 3475.79$, Sentiment 0.163, Daily References 20
# 2021-09-17, Close, 3488.24$, Sentiment -0.069, Daily References 16
# 2021-09-17, SELL CREATE, 3462.52
# 2021-09-20, SELL EXECUTED, Price: 3396.00, Cost: 3501.83, Comm 3.40
# 2021-09-20, OPERATION PROFIT, GROSS -105.83, NET -112.73
# 2021-09-20, Close, 3462.52$, Sentiment 0.213, Daily References 15
# 2021-09-22, Close, 3355.73$, Sentiment 0.200, Daily References 5
# 2021-09-23, Close, 3380.05$, Sentiment 0.247, Daily References 29
# 2021-09-24, Close, 3416.00$, Sentiment 0.293, Daily References 18
# 2021-09-27, Close, 3425.52$, Sentiment 0.139, Daily References 19
# 2021-09-30, Close, 3405.80$, Sentiment 0.110, Daily References 19
# 2021-10-01, Close, 3285.04$, Sentiment 0.081, Daily References 23
# 2021-10-04, Close, 3283.26$, Sentiment 0.161, Daily References 32
# 2021-10-06, Close, 3189.78$, Sentiment 0.148, Daily References 32
# 2021-10-07, Close, 3262.01$, Sentiment 0.105, Daily References 19
# 2021-10-08, Close, 3302.43$, Sentiment 0.086, Daily References 18
# 2021-10-11, Close, 3288.62$, Sentiment 0.270, Daily References 22
# 2021-10-12, Close, 3246.30$, Sentiment 0.228, Daily References 34
# 2021-10-18, Close, 3247.33$, Sentiment 0.243, Daily References 33
# 2021-10-19, Close, 3446.74$, Sentiment 0.198, Daily References 33
# 2021-10-20, Close, 3444.15$, Sentiment 0.226, Daily References 32
# 2021-10-25, Close, 3415.06$, Sentiment 0.089, Daily References 30
# 2021-10-26, Close, 3320.37$, Sentiment 0.066, Daily References 36
# 2021-10-26, BUY CREATE, 3376.07
# 2021-10-27, BUY EXECUTED, Price: 3388.00, Cost: 3388.00, Comm 3.39
# 2021-10-27, Close, 3376.07$, Sentiment 0.037, Daily References 31
# 2021-10-27, SELL CREATE, 3392.49
# Final Portfolio Value: 100550.13
# <img src="data:image/png;base64,..." width="431.24999357387435">
