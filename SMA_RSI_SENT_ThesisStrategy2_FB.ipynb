# %% [markdown]
# # Code for the model testing

# %%
#### Importation of libraries ####

from datetime import datetime
from datetime import date
from pandas_datareader.data import DataReader
from yahoofinancials import YahooFinancials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import backtrader as bt
import talib
pd.options.mode.chained_assignment = None
import ipympl

# %% [markdown]
# # Trading strat and backtesting

# %%
#### Download of the csv created with all Sentiment and Financial Data ####

SENT = pd.read_csv('FB.csv', index_col=0)
SENT = SENT['2021-02-01':'2021-11-01']
SENT.head()
# Out:
#                   high         low        open       close    volume  \
# 2021-02-01  264.170013  254.910004  259.519989  262.010010  22914300
# 2021-02-02  268.850006  263.269989  264.000000  267.079987  17320800
# 2021-02-03  269.200012  263.839996  265.619995  266.649994  14223400
# 2021-02-04  268.160004  264.000000  267.010010  266.489990  16060000
# 2021-02-05  269.170013  265.670013  266.799988  268.100006  12454400
#
#                  neg       neu       pos  compound  Daily References
# 2021-02-01  0.016500  0.891125  0.092375  0.102462                16
# 2021-02-02  0.133800  0.770733  0.095467 -0.090300                15
# 2021-02-03  0.026778  0.873333  0.099889  0.143167                 9
# 2021-02-04  0.124435  0.829348  0.046217 -0.141130                23
# 2021-02-05  0.066846  0.851154  0.082000  0.022108                13

# %%
#### Declaration of References as a Backtrader indicator ####

from backtrader.indicators import Indicator
class Sentiment(bt.Indicator):
    lines = ('sentiment',)
    
    plotinfo = dict(plot=True,
                    subplot=True,
                    plotname='',
               )   
    
    def next(self):
        self.date = self.datas[0].datetime.date(0)
        self.sentiment = SENT['compound'].loc[self.date.strftime('%Y-%m-%d')]
        self.lines.sentiment[0] = SENT['compound'].loc[self.date.strftime('%Y-%m-%d')]

print(type(Sentiment))
# Out:
# <class 'backtrader.indicator.MetaIndicator'>

# %%
#### Declaration of References as a Backtrader indicator ####

from backtrader.indicators import Indicator
class References(bt.Indicator):
    lines = ('references',)
    
    plotinfo = dict(plot=True,
                    subplot=True,
                    plotname='',
               )   
    
    def next(self):
        self.date = self.datas[0].datetime.date(0)
        self.references = SENT['Daily References'].loc[self.date.strftime('%Y-%m-%d')]
        self.lines.references[0] = SENT['Daily References'].loc[self.date.strftime('%Y-%m-%d')]

print(type(References))
# Out:
# <class 'backtrader.indicator.MetaIndicator'>

# %%
################ STRATEGY BACKTESTING ################

class ThesisStrategy(bt.Strategy):
    
    #### Constant variables #####
    params = (
    ('short_period',12),       
    ('flag',False)
    )
    
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt, txt))
        
        
    
    def __init__(self):
        
        #### Data collection from the feed ####
        self.dataclose = self.datas[0].close
        self.date = self.datas[0].datetime.date(0)
        self.sentiment = Sentiment(self.data).sentiment
        self.references = References(self.data).references
        
        #### Declaration of transaction variables ####
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
        #### Definition of indicators #####
           
        self.SMA = bt.ind.SMA(period=self.params.short_period)
        self.RSI = bt.ind.RSI()
  
        
        
    ##### Trade notification #####
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Trade is done
            return

        #### Check for transaction and print the details ####
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
                self.bar_executed = len(self)

        
        self.order = None

        
    def notify_trade(self, trade):
        #### Print the results of the transaction (Profit and loss) #### 
        if not trade.isclosed:
            return
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    

    def next(self):
        #### Daily notification about relevant data ####
        self.log('Close, %.2f$, Sentiment %.3f, Daily References %.0f' % (self.dataclose[0], self.sentiment[0], self.references[0]))
        #### Check for orders proceeding ####
        if self.order:
            return
        
        #### Strategy 2 ####
        
        if not self.position and not self.params.flag: 
            if self.dataclose[0] > self.SMA and not self.position and not self.RSI > 70:
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.order = self.buy()
                
        if ((self.dataclose[0] < self.SMA or self.RSI > 70 or self.references > 60 or self.sentiment > 0.3) and self.position):
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.params.flag = True
                self.order = self.sell()
                
        if not (self.dataclose[0] < self.SMA or self.RSI > 70 or self.references > 60 or self.sentiment > 0.3):
                self.params.flag = False
                    
            
if __name__ == '__main__':
    cerebro = bt.Cerebro()
    
    #### Loading of the strategy in cerebro ####
    cerebro.addstrategy(ThesisStrategy)
    
    #### Datafeed ####
    data = bt.feeds.GenericCSVData(dataname='FB.csv',
                                  fromdate=datetime(2021,2,1),
                                  todate=datetime(2021,11,1),
                                  nullvalue=0.0,
                                  dtformat=('%Y-%m-%d'),
                                  datetime=0,
                                  high=1,
                                  low=2,
                                  open=3,
                                  close=4,
                                  volume=5,
                                  sentiment=6,
                                  references = 7,
                                  openinterest=-1
                                )
    cerebro.adddata(data)
    
    #### Creation of the portfolio and add of comissions ####
    cerebro.broker.setcash(100000)
    cerebro.broker.setcommission(commission=0.001, margin = 0)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    #### Run the backtesting #### 
    backtest = cerebro.run()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    #### Plot ####
    plt.rcParams['figure.figsize'] = [25, 15]
    plt.rcParams.update({'font.size': 12}) 
    # %matplotlib inline
    Backtest_results = cerebro.plot(volume=False)
    plt.savefig('SMA_RSI_SENT_Strategy_2_FB_results.png')
# Out:
# Starting Portfolio Value: 100000.00
# 2021-02-23, Close, 265.86$, Sentiment 0.038, Daily References 25
# 2021-02-24, Close, 264.31$, Sentiment -0.024, Daily References 23
# 2021-02-25, Close, 254.69$, Sentiment 0.087, Daily References 21
# 2021-03-01, Close, 264.91$, Sentiment 0.113, Daily References 16
# 2021-03-02, Close, 259.00$, Sentiment -0.006, Daily References 10
# 2021-03-03, Close, 255.41$, Sentiment -0.027, Daily References 18
# 2021-03-04, Close, 257.64$, Sentiment -0.123, Daily References 6
# 2021-03-05, Close, 264.28$, Sentiment 0.203, Daily References 12
# 2021-03-05, BUY CREATE, 264.28
# 2021-03-08, BUY EXECUTED, Price: 265.55, Cost: 265.55, Comm 0.27
# 2021-03-08, Close, 255.31$, Sentiment 0.080, Daily References 13
# 2021-03-08, SELL CREATE, 255.31
# 2021-03-09, SELL EXECUTED, Price: 261.18, Cost: 265.55, Comm 0.26
# 2021-03-09, OPERATION PROFIT, GROSS -4.37, NET -4.90
# 2021-03-09, Close, 265.74$, Sentiment -0.094, Daily References 18
# 2021-03-10, Close, 264.90$, Sentiment -0.121, Daily References 21
# 2021-03-10, BUY CREATE, 264.90
# 2021-03-11, BUY EXECUTED, Price: 268.11, Cost: 268.11, Comm 0.27
# 2021-03-11, Close, 273.88$, Sentiment 0.161, Daily References 12
# 2021-03-12, Close, 268.40$, Sentiment 0.288, Daily References 11
# 2021-03-15, Close, 273.75$, Sentiment 0.044, Daily References 25
# 2021-03-16, Close, 279.28$, Sentiment -0.109, Daily References 20
# 2021-03-17, Close, 284.01$, Sentiment -0.019, Daily References 10
# 2021-03-18, Close, 278.62$, Sentiment -0.046, Daily References 18
# 2021-03-19, Close, 290.11$, Sentiment 0.014, Daily References 28
# 2021-03-22, Close, 293.54$, Sentiment 0.047, Daily References 20
# 2021-03-23, Close, 290.63$, Sentiment -0.183, Daily References 12
# 2021-03-24, Close, 282.14$, Sentiment -0.015, Daily References 33
# 2021-03-25, Close, 278.74$, Sentiment -0.112, Daily References 31
# 2021-03-25, SELL CREATE, 278.74
# 2021-03-26, SELL EXECUTED, Price: 278.30, Cost: 268.11, Comm 0.28
# 2021-03-26, OPERATION PROFIT, GROSS 10.19, NET 9.64
# 2021-03-26, Close, 283.02$, Sentiment -0.023, Daily References 14
# 2021-03-29, Close, 290.82$, Sentiment -0.026, Daily References 20
# 2021-03-29, BUY CREATE, 290.82
# 2021-03-30, BUY EXECUTED, Price: 289.83, Cost: 289.83, Comm 0.29
# 2021-03-30, Close, 288.00$, Sentiment 0.050, Daily References 8
# 2021-03-31, Close, 294.53$, Sentiment -0.069, Daily References 21
# 2021-04-01, Close, 298.66$, Sentiment 0.149, Daily References 16
# 2021-04-05, Close, 308.91$, Sentiment 0.076, Daily References 22
# 2021-04-06, Close, 306.26$, Sentiment 0.003, Daily References 18
# 2021-04-07, Close, 313.09$, Sentiment -0.023, Daily References 18
# 2021-04-08, Close, 313.02$, Sentiment -0.056, Daily References 23
# 2021-04-09, Close, 312.46$, Sentiment -0.099, Daily References 16
# 2021-04-12, Close, 311.54$, Sentiment 0.062, Daily References 10
# 2021-04-13, Close, 309.76$, Sentiment 0.088, Daily References 15
# 2021-04-14, Close, 302.82$, Sentiment 0.032, Daily References 15
# 2021-04-14, SELL CREATE, 302.82
# 2021-04-15, SELL EXECUTED, Price: 306.34, Cost: 289.83, Comm 0.31
# 2021-04-15, OPERATION PROFIT, GROSS 16.51, NET 15.91
# 2021-04-15, Close, 307.82$, Sentiment 0.117, Daily References 18
# 2021-04-16, Close, 306.18$, Sentiment -0.101, Daily References 12
# 2021-04-19, Close, 302.24$, Sentiment 0.077, Daily References 16
# 2021-04-20, Close, 302.65$, Sentiment 0.015, Daily References 10
# 2021-04-21, Close, 301.47$, Sentiment -0.001, Daily References 19
# 2021-04-22, Close, 296.52$, Sentiment 0.026, Daily References 16
# 2021-04-23, Close, 301.13$, Sentiment 0.071, Daily References 16
# 2021-04-26, Close, 303.04$, Sentiment 0.010, Daily References 25
# 2021-04-27, Close, 303.57$, Sentiment 0.065, Daily References 23
# 2021-04-28, Close, 307.10$, Sentiment 0.141, Daily References 27
# 2021-04-28, BUY CREATE, 307.10
# 2021-04-29, BUY EXECUTED, Price: 330.12, Cost: 330.12, Comm 0.33
# 2021-04-29, Close, 329.51$, Sentiment 0.059, Daily References 37
# 2021-04-29, SELL CREATE, 329.51
# 2021-04-30, SELL EXECUTED, Price: 326.14, Cost: 330.12, Comm 0.33
# 2021-04-30, OPERATION PROFIT, GROSS -3.98, NET -4.64
# 2021-04-30, Close, 325.08$, Sentiment 0.135, Daily References 17
# 2021-05-03, Close, 322.58$, Sentiment -0.128, Daily References 16
# 2021-05-03, BUY CREATE, 322.58
# 2021-05-04, BUY EXECUTED, Price: 320.02, Cost: 320.02, Comm 0.32
# 2021-05-04, Close, 318.36$, Sentiment 0.024, Daily References 16
# 2021-05-05, Close, 315.02$, Sentiment -0.173, Daily References 39
# 2021-05-06, Close, 320.02$, Sentiment -0.113, Daily References 15
# 2021-05-07, Close, 319.08$, Sentiment -0.246, Daily References 5
# 2021-05-10, Close, 305.97$, Sentiment -0.055, Daily References 21
# 2021-05-10, SELL CREATE, 305.97
# 2021-05-11, SELL EXECUTED, Price: 300.75, Cost: 320.02, Comm 0.30
# 2021-05-11, OPERATION PROFIT, GROSS -19.27, NET -19.89
# 2021-05-11, Close, 306.53$, Sentiment -0.012, Daily References 20
# 2021-05-12, Close, 302.55$, Sentiment -0.032, Daily References 23
# 2021-05-13, Close, 305.26$, Sentiment 0.248, Daily References 10
# 2021-05-14, Close, 315.94$, Sentiment -0.113, Daily References 14
# 2021-05-17, Close, 315.46$, Sentiment 0.302, Daily References 9
# 2021-05-17, BUY CREATE, 315.46
# 2021-05-18, BUY EXECUTED, Price: 315.59, Cost: 315.59, Comm 0.32
# 2021-05-18, Close, 309.96$, Sentiment 0.007, Daily References 6
# 2021-05-18, SELL CREATE, 309.96
# 2021-05-19, SELL EXECUTED, Price: 304.19, Cost: 315.59, Comm 0.30
# 2021-05-19, OPERATION PROFIT, GROSS -11.40, NET -12.02
# 2021-05-19, Close, 313.59$, Sentiment -0.037, Daily References 16
# 2021-05-20, Close, 318.61$, Sentiment -0.009, Daily References 12
# 2021-05-20, BUY CREATE, 318.61
# 2021-05-21, BUY EXECUTED, Price: 319.29, Cost: 319.29, Comm 0.32
# 2021-05-21, Close, 316.23$, Sentiment 0.096, Daily References 16
# 2021-05-24, Close, 324.63$, Sentiment 0.033, Daily References 9
# 2021-05-25, Close, 327.79$, Sentiment 0.040, Daily References 22
# 2021-05-26, Close, 327.66$, Sentiment -0.014, Daily References 25
# 2021-05-27, Close, 332.75$, Sentiment -0.060, Daily References 14
# 2021-05-28, Close, 328.73$, Sentiment 0.226, Daily References 9
# 2021-06-01, Close, 329.13$, Sentiment 0.131, Daily References 7
# 2021-06-02, Close, 329.15$, Sentiment 0.070, Daily References 13
# 2021-06-03, Close, 326.04$, Sentiment 0.159, Daily References 11
# 2021-06-04, Close, 330.35$, Sentiment -0.065, Daily References 37
# 2021-06-07, Close, 336.58$, Sentiment 0.080, Daily References 16
# 2021-06-08, Close, 333.68$, Sentiment 0.213, Daily References 18
# 2021-06-09, Close, 330.25$, Sentiment 0.104, Daily References 5
# 2021-06-10, Close, 332.46$, Sentiment 0.079, Daily References 23
# 2021-06-11, Close, 331.26$, Sentiment 0.125, Daily References 11
# 2021-06-14, Close, 336.77$, Sentiment 0.171, Daily References 11
# 2021-06-15, Close, 336.75$, Sentiment 0.120, Daily References 19
# 2021-06-16, Close, 331.08$, Sentiment -0.065, Daily References 20
# 2021-06-16, SELL CREATE, 331.08
# 2021-06-17, SELL EXECUTED, Price: 330.49, Cost: 319.29, Comm 0.33
# 2021-06-17, OPERATION PROFIT, GROSS 11.20, NET 10.55
# 2021-06-17, Close, 336.51$, Sentiment 0.096, Daily References 16
# 2021-06-18, Close, 329.66$, Sentiment 0.069, Daily References 9
# 2021-06-21, Close, 332.29$, Sentiment 0.188, Daily References 19
# 2021-06-22, Close, 339.03$, Sentiment 0.086, Daily References 20
# 2021-06-22, BUY CREATE, 339.03
# 2021-06-23, BUY EXECUTED, Price: 339.35, Cost: 339.35, Comm 0.34
# 2021-06-23, Close, 340.59$, Sentiment 0.037, Daily References 12
# 2021-06-24, Close, 343.18$, Sentiment 0.185, Daily References 17
# 2021-06-25, Close, 341.37$, Sentiment 0.110, Daily References 9
# 2021-06-28, Close, 355.64$, Sentiment 0.137, Daily References 22
# 2021-06-28, SELL CREATE, 355.64
# 2021-06-29, SELL EXECUTED, Price: 356.27, Cost: 339.35, Comm 0.36
# 2021-06-29, OPERATION PROFIT, GROSS 16.92, NET 16.22
# 2021-06-29, Close, 351.89$, Sentiment 0.079, Daily References 34
# 2021-06-30, Close, 347.71$, Sentiment -0.018, Daily References 5
# 2021-06-30, BUY CREATE, 347.71
# 2021-07-01, BUY EXECUTED, Price: 346.82, Cost: 346.82, Comm 0.35
# 2021-07-01, Close, 354.39$, Sentiment 0.084, Daily References 7
# 2021-07-02, Close, 354.70$, Sentiment -0.196, Daily References 10
# 2021-07-06, Close, 352.78$, Sentiment 0.032, Daily References 7
# 2021-07-07, Close, 350.49$, Sentiment 0.024, Daily References 14
# 2021-07-08, Close, 345.65$, Sentiment -0.026, Daily References 13
# 2021-07-08, SELL CREATE, 345.65
# 2021-07-09, SELL EXECUTED, Price: 345.32, Cost: 346.82, Comm 0.35
# 2021-07-09, OPERATION PROFIT, GROSS -1.50, NET -2.19
# 2021-07-09, Close, 350.42$, Sentiment -0.161, Daily References 9
# 2021-07-12, Close, 353.16$, Sentiment -0.251, Daily References 6
# 2021-07-12, BUY CREATE, 353.16
# 2021-07-13, BUY EXECUTED, Price: 351.50, Cost: 351.50, Comm 0.35
# 2021-07-13, Close, 352.09$, Sentiment 0.010, Daily References 8
# 2021-07-14, Close, 347.63$, Sentiment -0.004, Daily References 6
# 2021-07-14, SELL CREATE, 347.63
# 2021-07-15, SELL EXECUTED, Price: 349.23, Cost: 351.50, Comm 0.35
# 2021-07-15, OPERATION PROFIT, GROSS -2.27, NET -2.97
# 2021-07-15, Close, 344.46$, Sentiment -0.333, Daily References 18
# 2021-07-16, Close, 341.16$, Sentiment -0.140, Daily References 11
# 2021-07-19, Close, 336.95$, Sentiment -0.251, Daily References 16
# 2021-07-20, Close, 341.66$, Sentiment -0.036, Daily References 11
# 2021-07-21, Close, 346.23$, Sentiment -0.127, Daily References 9
# 2021-07-22, Close, 351.19$, Sentiment -0.016, Daily References 17
# 2021-07-23, Close, 369.79$, Sentiment 0.018, Daily References 21
# 2021-07-23, BUY CREATE, 369.79
# 2021-07-26, BUY EXECUTED, Price: 369.58, Cost: 369.58, Comm 0.37
# 2021-07-26, Close, 372.46$, Sentiment 0.009, Daily References 12
# 2021-07-26, SELL CREATE, 372.46
# 2021-07-27, SELL EXECUTED, Price: 371.91, Cost: 369.58, Comm 0.37
# 2021-07-27, OPERATION PROFIT, GROSS 2.33, NET 1.59
# 2021-07-27, Close, 367.81$, Sentiment 0.073, Daily References 19
# 2021-07-28, Close, 373.28$, Sentiment 0.174, Daily References 32
# 2021-07-28, BUY CREATE, 373.28
# 2021-07-29, BUY EXECUTED, Price: 361.00, Cost: 361.00, Comm 0.36
# 2021-07-29, Close, 358.32$, Sentiment 0.017, Daily References 33
# 2021-07-30, Close, 356.30$, Sentiment 0.113, Daily References 8
# 2021-08-02, Close, 351.95$, Sentiment 0.017, Daily References 12
# 2021-08-02, SELL CREATE, 351.95
# 2021-08-03, SELL EXECUTED, Price: 352.73, Cost: 361.00, Comm 0.35
# 2021-08-03, OPERATION PROFIT, GROSS -8.27, NET -8.98
# 2021-08-03, Close, 351.24$, Sentiment 0.079, Daily References 11
# 2021-08-04, Close, 358.92$, Sentiment -0.124, Daily References 17
# 2021-08-05, Close, 362.97$, Sentiment 0.046, Daily References 14
# 2021-08-05, BUY CREATE, 362.97
# 2021-08-06, BUY EXECUTED, Price: 361.40, Cost: 361.40, Comm 0.36
# 2021-08-06, Close, 363.51$, Sentiment 0.015, Daily References 15
# 2021-08-09, Close, 361.61$, Sentiment -0.099, Daily References 7
# 2021-08-09, SELL CREATE, 361.61
# 2021-08-10, SELL EXECUTED, Price: 361.83, Cost: 361.40, Comm 0.36
# 2021-08-10, OPERATION PROFIT, GROSS 0.43, NET -0.29
# 2021-08-10, Close, 361.13$, Sentiment 0.185, Daily References 11
# 2021-08-11, Close, 359.96$, Sentiment 0.093, Daily References 6
# 2021-08-12, Close, 362.65$, Sentiment -0.076, Daily References 11
# 2021-08-13, Close, 363.18$, Sentiment 0.081, Daily References 11
# 2021-08-13, BUY CREATE, 363.18
# 2021-08-16, BUY EXECUTED, Price: 362.52, Cost: 362.52, Comm 0.36
# 2021-08-16, Close, 366.56$, Sentiment 0.161, Daily References 9
# 2021-08-17, Close, 358.45$, Sentiment -0.138, Daily References 9
# 2021-08-17, SELL CREATE, 358.45
# 2021-08-18, SELL EXECUTED, Price: 356.25, Cost: 362.52, Comm 0.36
# 2021-08-18, OPERATION PROFIT, GROSS -6.27, NET -6.99
# 2021-08-18, Close, 355.45$, Sentiment 0.120, Daily References 14
# 2021-08-19, Close, 355.12$, Sentiment -0.018, Daily References 39
# 2021-08-20, Close, 359.37$, Sentiment 0.233, Daily References 12
# 2021-08-23, Close, 363.35$, Sentiment 0.004, Daily References 12
# 2021-08-24, Close, 365.51$, Sentiment -0.153, Daily References 9
# 2021-08-24, BUY CREATE, 365.51
# 2021-08-25, BUY EXECUTED, Price: 365.60, Cost: 365.60, Comm 0.37
# 2021-08-25, Close, 368.39$, Sentiment 0.023, Daily References 11
# 2021-08-26, Close, 364.38$, Sentiment 0.172, Daily References 5
# 2021-08-27, Close, 372.63$, Sentiment 0.036, Daily References 9
# 2021-08-30, Close, 380.66$, Sentiment 0.097, Daily References 9
# 2021-08-31, Close, 379.38$, Sentiment -0.077, Daily References 8
# 2021-09-01, Close, 382.05$, Sentiment 0.063, Daily References 11
# 2021-09-02, Close, 375.28$, Sentiment 0.045, Daily References 22
# 2021-09-03, Close, 376.26$, Sentiment -0.109, Daily References 4
# 2021-09-07, Close, 382.18$, Sentiment 0.289, Daily References 7
# 2021-09-08, Close, 377.57$, Sentiment -0.038, Daily References 17
# 2021-09-09, Close, 378.00$, Sentiment 0.163, Daily References 21
# 2021-09-10, Close, 378.69$, Sentiment 0.237, Daily References 14
# 2021-09-13, Close, 376.51$, Sentiment 0.068, Daily References 8
# 2021-09-13, SELL CREATE, 376.51
# 2021-09-14, SELL EXECUTED, Price: 377.40, Cost: 365.60, Comm 0.38
# 2021-09-14, OPERATION PROFIT, GROSS 11.80, NET 11.06
# 2021-09-14, Close, 376.53$, Sentiment 0.037, Daily References 11
# 2021-09-15, Close, 373.92$, Sentiment 0.006, Daily References 16
# 2021-09-16, Close, 373.06$, Sentiment -0.021, Daily References 23
# 2021-09-17, Close, 364.72$, Sentiment -0.032, Daily References 17
# 2021-09-20, Close, 355.70$, Sentiment 0.126, Daily References 8
# 2021-09-21, Close, 357.48$, Sentiment 0.188, Daily References 26
# 2021-09-22, Close, 343.21$, Sentiment -0.048, Daily References 30
# 2021-09-23, Close, 345.96$, Sentiment 0.002, Daily References 26
# 2021-09-24, Close, 352.96$, Sentiment 0.138, Daily References 8
# 2021-09-27, Close, 353.58$, Sentiment -0.028, Daily References 23
# 2021-09-28, Close, 340.65$, Sentiment 0.098, Daily References 23
# 2021-09-29, Close, 339.61$, Sentiment 0.083, Daily References 25
# 2021-09-30, Close, 339.39$, Sentiment -0.109, Daily References 18
# 2021-10-01, Close, 343.01$, Sentiment -0.178, Daily References 11
# 2021-10-04, Close, 326.23$, Sentiment -0.165, Daily References 51
# 2021-10-05, Close, 332.96$, Sentiment -0.021, Daily References 64
# 2021-10-06, Close, 333.64$, Sentiment -0.084, Daily References 32
# 2021-10-07, Close, 329.22$, Sentiment -0.114, Daily References 18
# 2021-10-08, Close, 330.05$, Sentiment 0.121, Daily References 23
# 2021-10-15, Close, 324.76$, Sentiment -0.391, Daily References 2
# 2021-10-18, Close, 335.34$, Sentiment 0.043, Daily References 16
# 2021-10-19, Close, 339.99$, Sentiment 0.017, Daily References 30
# 2021-10-20, Close, 340.78$, Sentiment 0.001, Daily References 38
# 2021-10-20, BUY CREATE, 340.78
# 2021-10-25, BUY EXECUTED, Price: 320.30, Cost: 320.30, Comm 0.32
# 2021-10-25, Close, 328.69$, Sentiment 0.094, Daily References 9
# 2021-10-25, SELL CREATE, 328.69
# 2021-10-26, SELL EXECUTED, Price: 328.26, Cost: 320.30, Comm 0.33
# 2021-10-26, OPERATION PROFIT, GROSS 7.96, NET 7.31
# 2021-10-26, Close, 315.81$, Sentiment 0.125, Daily References 58
# 2021-10-27, Close, 312.22$, Sentiment 0.010, Daily References 30
# Final Portfolio Value: 100009.42
# <img src="data:image/png;base64,..." width="431.24999357387435">
