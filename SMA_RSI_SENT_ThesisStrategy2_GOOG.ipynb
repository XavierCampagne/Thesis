# %% [markdown]
# # Code for the model testing

# %%
#### Importation of libraries ####

from datetime import datetime
from datetime import date
from pandas_datareader.data import DataReader
from yahoofinancials import YahooFinancials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import backtrader as bt
import talib
pd.options.mode.chained_assignment = None
import ipympl

# %% [markdown]
# # Trading strat and backtesting

# %%
#### Download of the csv created with all Sentiment and Financial Data ####

SENT = pd.read_csv('GOOG.csv', index_col=0)
SENT = SENT['2021-02-01':'2021-11-01']
SENT.head()
# Out:
#                    high          low         open        close   volume  \
# 2021-02-01  1922.391968  1850.930054  1853.569946  1901.349976  1602200
# 2021-02-02  1955.760010  1914.489990  1922.560059  1927.510010  2273700
# 2021-02-03  2116.500000  2018.380005  2073.000000  2070.070068  4118200
# 2021-02-04  2078.550049  2042.589966  2068.889893  2062.370117  1852300
# 2021-02-05  2102.510010  2059.330078  2070.000000  2098.000000  1535100
#
#                  neg       neu       pos  compound  Daily References
# 2021-02-01  0.031086  0.888629  0.080286  0.085091                35
# 2021-02-02  0.219000  0.781000  0.000000 -0.421500                 1
# 2021-02-03  0.055800  0.841367  0.102800  0.070293                30
# 2021-02-04  0.084344  0.829438  0.086219 -0.005116                32
# 2021-02-05  0.039842  0.856737  0.103421  0.090237                19

# %%
#### Declaration of References as a Backtrader indicator ####

from backtrader.indicators import Indicator
class Sentiment(bt.Indicator):
    lines = ('sentiment',)
    
    plotinfo = dict(plot=True,
                    subplot=True,
                    plotname='',
               )   
    
    def next(self):
        self.date = self.datas[0].datetime.date(0)
        self.sentiment = SENT['compound'].loc[self.date.strftime('%Y-%m-%d')]
        self.lines.sentiment[0] = SENT['compound'].loc[self.date.strftime('%Y-%m-%d')]

print(type(Sentiment))
# Out:
# <class 'backtrader.indicator.MetaIndicator'>

# %%
#### Declaration of References as a Backtrader indicator ####

from backtrader.indicators import Indicator
class References(bt.Indicator):
    lines = ('references',)
    
    plotinfo = dict(plot=True,
                    subplot=True,
                    plotname='',
               )   
    
    def next(self):
        self.date = self.datas[0].datetime.date(0)
        self.references = SENT['Daily References'].loc[self.date.strftime('%Y-%m-%d')]
        self.lines.references[0] = SENT['Daily References'].loc[self.date.strftime('%Y-%m-%d')]

print(type(References))
# Out:
# <class 'backtrader.indicator.MetaIndicator'>

# %%
################ STRATEGY BACKTESTING ################

class ThesisStrategy(bt.Strategy):
    
    #### Constant variables #####
    params = (
    ('short_period',12),    
    ('long_period',26),    
    ('sma_period',20),
    ('flag',False)
    )
    
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt, txt))
        
        
    
    def __init__(self):
        
        #### Data collection from the feed ####
        self.dataclose = self.datas[0].close
        self.date = self.datas[0].datetime.date(0)
        self.sentiment = Sentiment(self.data).sentiment
        self.references = References(self.data).references
        
        #### Declaration of transaction variables ####
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
        #### Definition of indicators #####
           
        self.SMA = bt.ind.SMA(period=self.params.short_period)
        self.RSI = bt.ind.RSI()
  
        
        
    ##### Trade notification #####
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Trade is done
            return

        #### Check for transaction and print the details ####
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
                self.bar_executed = len(self)

        
        self.order = None

        
    def notify_trade(self, trade):
        #### Print the results of the transaction (Profit and loss) #### 
        if not trade.isclosed:
            return
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    

    def next(self):
        #### Daily notification about relevant data ####
        self.log('Close, %.2f$, Sentiment %.3f, Daily References %.0f' % (self.dataclose[0], self.sentiment[0], self.references[0]))
        #### Check for orders proceeding ####
        if self.order:
            return
        
        #### Strategy 2 ####
        
        if not self.position and not self.params.flag: 
            if self.dataclose[0] > self.SMA and not self.position and not self.RSI > 70:
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.order = self.buy()
                
        if ((self.dataclose[0] < self.SMA or self.RSI > 70 or self.references > 60 or self.sentiment > 0.3) and self.position):
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.params.flag = True
                self.order = self.sell()
                
        if not (self.dataclose[0] < self.SMA or self.RSI > 70 or self.references > 60 or self.sentiment > 0.3):
                self.params.flag = False
                    
            
if __name__ == '__main__':
    cerebro = bt.Cerebro()
    
    #### Loading of the strategy in cerebro ####
    cerebro.addstrategy(ThesisStrategy)
    
    #### Datafeed ####
    data = bt.feeds.GenericCSVData(dataname='GOOG.csv',
                                  fromdate=datetime(2021,2,1),
                                  todate=datetime(2021,11,1),
                                  nullvalue=0.0,
                                  dtformat=('%Y-%m-%d'),
                                  datetime=0,
                                  high=1,
                                  low=2,
                                  open=3,
                                  close=4,
                                  volume=5,
                                  sentiment=6,
                                  references = 7,
                                  openinterest=-1
                                )
    cerebro.adddata(data)
    
    #### Creation of the portfolio and add of comissions ####
    cerebro.broker.setcash(100000)
    cerebro.broker.setcommission(commission=0.001, margin = 0)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    #### Run the backtesting #### 
    backtest = cerebro.run()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    #### Plot ####
    plt.rcParams['figure.figsize'] = [25, 15]
    plt.rcParams.update({'font.size': 12}) 
    # %matplotlib inline
    Backtest_results = cerebro.plot(volume=False)
    plt.savefig('SMA_RSI_SENT_Strategy_2_GOOG_results.png')
# Out:
# Starting Portfolio Value: 100000.00
# 2021-02-22, Close, 2064.88$, Sentiment -0.144, Daily References 13
# 2021-02-23, Close, 2070.86$, Sentiment 0.210, Daily References 3
# 2021-03-02, Close, 2075.84$, Sentiment -0.235, Daily References 7
# 2021-03-03, Close, 2026.71$, Sentiment 0.060, Daily References 26
# 2021-03-04, Close, 2049.09$, Sentiment 0.024, Daily References 18
# 2021-03-05, Close, 2108.54$, Sentiment 0.200, Daily References 20
# 2021-03-08, Close, 2024.17$, Sentiment 0.119, Daily References 16
# 2021-03-09, Close, 2052.70$, Sentiment 0.135, Daily References 5
# 2021-03-17, Close, 2091.08$, Sentiment 0.165, Daily References 7
# 2021-03-17, BUY CREATE, 2091.08
# 2021-03-18, BUY EXECUTED, Price: 2061.00, Cost: 2061.00, Comm 2.06
# 2021-03-18, Close, 2036.22$, Sentiment 0.078, Daily References 34
# 2021-03-18, SELL CREATE, 2036.22
# 2021-03-19, SELL EXECUTED, Price: 2042.05, Cost: 2061.00, Comm 2.04
# 2021-03-19, OPERATION PROFIT, GROSS -18.95, NET -23.05
# 2021-03-19, Close, 2043.20$, Sentiment -0.098, Daily References 9
# 2021-03-22, Close, 2038.59$, Sentiment 0.059, Daily References 28
# 2021-03-23, Close, 2052.96$, Sentiment 0.040, Daily References 9
# 2021-03-25, Close, 2044.36$, Sentiment -0.003, Daily References 27
# 2021-03-26, Close, 2035.55$, Sentiment 0.066, Daily References 20
# 2021-03-29, Close, 2055.95$, Sentiment 0.048, Daily References 23
# 2021-03-30, Close, 2055.54$, Sentiment 0.100, Daily References 15
# 2021-03-30, BUY CREATE, 2055.54
# 2021-04-05, BUY EXECUTED, Price: 2152.94, Cost: 2152.94, Comm 2.15
# 2021-04-05, Close, 2225.55$, Sentiment 0.033, Daily References 10
# 2021-04-05, SELL CREATE, 2225.55
# 2021-04-06, SELL EXECUTED, Price: 2222.50, Cost: 2152.94, Comm 2.22
# 2021-04-06, OPERATION PROFIT, GROSS 69.56, NET 65.18
# 2021-04-06, Close, 2224.75$, Sentiment 0.167, Daily References 26
# 2021-04-07, Close, 2249.68$, Sentiment 0.078, Daily References 20
# 2021-04-08, Close, 2265.44$, Sentiment -0.064, Daily References 26
# 2021-04-09, Close, 2285.88$, Sentiment 0.112, Daily References 48
# 2021-04-12, Close, 2254.79$, Sentiment 0.187, Daily References 21
# 2021-04-13, Close, 2267.27$, Sentiment 0.164, Daily References 9
# 2021-04-14, Close, 2254.84$, Sentiment 0.050, Daily References 29
# 2021-04-19, Close, 2302.40$, Sentiment -0.038, Daily References 6
# 2021-04-20, Close, 2293.63$, Sentiment -0.021, Daily References 16
# 2021-04-21, Close, 2293.29$, Sentiment 0.018, Daily References 25
# 2021-04-22, Close, 2267.92$, Sentiment 0.102, Daily References 12
# 2021-04-22, BUY CREATE, 2267.92
# 2021-04-23, BUY EXECUTED, Price: 2283.47, Cost: 2283.47, Comm 2.28
# 2021-04-23, Close, 2315.30$, Sentiment 0.136, Daily References 22
# 2021-04-23, SELL CREATE, 2315.30
# 2021-04-26, SELL EXECUTED, Price: 2319.93, Cost: 2283.47, Comm 2.32
# 2021-04-26, OPERATION PROFIT, GROSS 36.46, NET 31.86
# 2021-04-26, Close, 2326.74$, Sentiment 0.073, Daily References 12
# 2021-04-28, Close, 2379.91$, Sentiment 0.003, Daily References 12
# 2021-04-29, Close, 2429.89$, Sentiment -0.019, Daily References 24
# 2021-04-30, Close, 2410.12$, Sentiment 0.089, Daily References 33
# 2021-05-03, Close, 2395.17$, Sentiment 0.171, Daily References 13
# 2021-05-04, Close, 2354.25$, Sentiment 0.525, Daily References 3
# 2021-05-05, Close, 2356.74$, Sentiment 0.099, Daily References 21
# 2021-05-06, Close, 2381.35$, Sentiment -0.006, Daily References 20
# 2021-05-06, BUY CREATE, 2381.35
# 2021-05-07, BUY EXECUTED, Price: 2400.00, Cost: 2400.00, Comm 2.40
# 2021-05-07, Close, 2398.69$, Sentiment -0.013, Daily References 20
# 2021-05-10, Close, 2341.66$, Sentiment 0.084, Daily References 17
# 2021-05-10, SELL CREATE, 2341.66
# 2021-05-11, SELL EXECUTED, Price: 2291.86, Cost: 2400.00, Comm 2.29
# 2021-05-11, OPERATION PROFIT, GROSS -108.14, NET -112.83
# 2021-05-11, Close, 2308.76$, Sentiment 0.037, Daily References 13
# 2021-05-25, Close, 2409.07$, Sentiment 0.048, Daily References 14
# 2021-05-26, Close, 2433.53$, Sentiment 0.128, Daily References 28
# 2021-05-26, BUY CREATE, 2433.53
# 2021-05-27, BUY EXECUTED, Price: 2436.94, Cost: 2436.94, Comm 2.44
# 2021-05-27, Close, 2402.51$, Sentiment 0.121, Daily References 25
# 2021-05-28, Close, 2411.56$, Sentiment 0.104, Daily References 19
# 2021-06-01, Close, 2429.81$, Sentiment 0.167, Daily References 14
# 2021-06-02, Close, 2421.28$, Sentiment 0.061, Daily References 40
# 2021-06-03, Close, 2404.61$, Sentiment 0.134, Daily References 46
# 2021-06-04, Close, 2451.76$, Sentiment 0.128, Daily References 47
# 2021-06-07, Close, 2466.09$, Sentiment -0.015, Daily References 27
# 2021-06-09, Close, 2491.40$, Sentiment 0.051, Daily References 4
# 2021-06-10, Close, 2521.60$, Sentiment 0.093, Daily References 29
# 2021-06-10, SELL CREATE, 2521.60
# 2021-06-11, SELL EXECUTED, Price: 2524.92, Cost: 2436.94, Comm 2.52
# 2021-06-11, OPERATION PROFIT, GROSS 87.98, NET 83.02
# 2021-06-11, Close, 2513.93$, Sentiment 0.195, Daily References 46
# 2021-06-14, Close, 2527.04$, Sentiment -0.018, Daily References 63
# 2021-06-14, BUY CREATE, 2527.04
# 2021-06-15, BUY EXECUTED, Price: 2530.44, Cost: 2530.44, Comm 2.53
# 2021-06-15, Close, 2520.66$, Sentiment 0.079, Daily References 85
# 2021-06-15, SELL CREATE, 2520.66
# 2021-06-16, SELL EXECUTED, Price: 2524.95, Cost: 2530.44, Comm 2.52
# 2021-06-16, OPERATION PROFIT, GROSS -5.49, NET -10.55
# 2021-06-16, Close, 2513.93$, Sentiment 0.050, Daily References 45
# 2021-06-17, Close, 2527.42$, Sentiment 0.093, Daily References 33
# 2021-06-17, BUY CREATE, 2527.42
# 2021-06-18, BUY EXECUTED, Price: 2514.11, Cost: 2514.11, Comm 2.51
# 2021-06-18, Close, 2511.35$, Sentiment 0.029, Daily References 14
# 2021-06-21, Close, 2529.10$, Sentiment 0.154, Daily References 13
# 2021-06-22, Close, 2539.99$, Sentiment 0.132, Daily References 36
# 2021-06-23, Close, 2529.23$, Sentiment 0.035, Daily References 8
# 2021-06-24, Close, 2545.64$, Sentiment -0.024, Daily References 39
# 2021-06-25, Close, 2539.90$, Sentiment 0.102, Daily References 51
# 2021-06-28, Close, 2536.39$, Sentiment 0.034, Daily References 48
# 2021-06-29, Close, 2520.37$, Sentiment 0.057, Daily References 34
# 2021-06-29, SELL CREATE, 2520.37
# 2021-06-30, SELL EXECUTED, Price: 2513.07, Cost: 2514.11, Comm 2.51
# 2021-06-30, OPERATION PROFIT, GROSS -1.04, NET -6.07
# 2021-06-30, Close, 2506.32$, Sentiment -0.382, Daily References 1
# 2021-07-08, Close, 2583.54$, Sentiment 0.044, Daily References 24
# 2021-07-09, Close, 2591.49$, Sentiment 0.069, Daily References 30
# 2021-07-09, BUY CREATE, 2591.49
# 2021-07-12, BUY EXECUTED, Price: 2596.67, Cost: 2596.67, Comm 2.60
# 2021-07-12, Close, 2611.28$, Sentiment 0.099, Daily References 58
# 2021-07-12, SELL CREATE, 2611.28
# 2021-07-13, SELL EXECUTED, Price: 2617.63, Cost: 2596.67, Comm 2.62
# 2021-07-13, OPERATION PROFIT, GROSS 20.96, NET 15.75
# 2021-07-13, Close, 2619.89$, Sentiment -0.011, Daily References 54
# 2021-07-14, Close, 2641.65$, Sentiment 0.021, Daily References 24
# 2021-07-15, Close, 2625.33$, Sentiment -0.092, Daily References 13
# 2021-07-16, Close, 2636.91$, Sentiment 0.022, Daily References 15
# 2021-07-19, Close, 2585.08$, Sentiment 0.077, Daily References 12
# 2021-07-19, BUY CREATE, 2585.08
# 2021-07-20, BUY EXECUTED, Price: 2600.08, Cost: 2600.08, Comm 2.60
# 2021-07-20, Close, 2622.03$, Sentiment 0.039, Daily References 25
# 2021-07-21, Close, 2652.01$, Sentiment 0.014, Daily References 20
# 2021-07-26, Close, 2792.89$, Sentiment 0.159, Daily References 2
# 2021-07-26, SELL CREATE, 2792.89
# 2021-07-27, SELL EXECUTED, Price: 2800.22, Cost: 2600.08, Comm 2.80
# 2021-07-27, OPERATION PROFIT, GROSS 200.14, NET 194.74
# 2021-07-27, Close, 2735.93$, Sentiment 0.063, Daily References 60
# 2021-07-28, Close, 2727.63$, Sentiment 0.103, Daily References 104
# 2021-07-28, BUY CREATE, 2727.63
# 2021-07-29, BUY EXECUTED, Price: 2727.61, Cost: 2727.61, Comm 2.73
# 2021-07-29, Close, 2730.81$, Sentiment 0.058, Daily References 39
# 2021-07-30, Close, 2704.42$, Sentiment 0.031, Daily References 14
# 2021-08-02, Close, 2719.79$, Sentiment 0.163, Daily References 24
# 2021-08-03, Close, 2725.60$, Sentiment 0.115, Daily References 18
# 2021-08-04, Close, 2720.57$, Sentiment -0.234, Daily References 21
# 2021-08-05, Close, 2738.80$, Sentiment 0.117, Daily References 32
# 2021-08-06, Close, 2740.72$, Sentiment 0.251, Daily References 18
# 2021-08-09, Close, 2760.04$, Sentiment 0.087, Daily References 10
# 2021-08-10, Close, 2761.93$, Sentiment 0.015, Daily References 23
# 2021-08-11, Close, 2753.79$, Sentiment -0.073, Daily References 17
# 2021-08-12, Close, 2767.79$, Sentiment -0.001, Daily References 9
# 2021-08-13, Close, 2768.12$, Sentiment 0.008, Daily References 16
# 2021-08-16, Close, 2778.32$, Sentiment 0.135, Daily References 21
# 2021-08-17, Close, 2746.01$, Sentiment 0.078, Daily References 16
# 2021-08-17, SELL CREATE, 2746.01
# 2021-08-18, SELL EXECUTED, Price: 2742.31, Cost: 2727.61, Comm 2.74
# 2021-08-18, OPERATION PROFIT, GROSS 14.70, NET 9.23
# 2021-08-18, Close, 2731.40$, Sentiment 0.122, Daily References 13
# 2021-08-19, Close, 2738.27$, Sentiment -0.116, Daily References 16
# 2021-08-20, Close, 2768.74$, Sentiment -0.271, Daily References 6
# 2021-08-23, Close, 2821.99$, Sentiment 0.131, Daily References 13
# 2021-08-24, Close, 2847.97$, Sentiment 0.039, Daily References 18
# 2021-08-25, Close, 2859.00$, Sentiment 0.020, Daily References 29
# 2021-08-26, Close, 2842.46$, Sentiment 0.070, Daily References 22
# 2021-08-26, BUY CREATE, 2842.46
# 2021-08-27, BUY EXECUTED, Price: 2842.25, Cost: 2842.25, Comm 2.84
# 2021-08-27, Close, 2891.01$, Sentiment 0.086, Daily References 11
# 2021-08-27, SELL CREATE, 2891.01
# 2021-08-30, SELL EXECUTED, Price: 2894.09, Cost: 2842.25, Comm 2.89
# 2021-08-30, OPERATION PROFIT, GROSS 51.84, NET 46.10
# 2021-08-30, Close, 2909.39$, Sentiment 0.182, Daily References 22
# 2021-08-31, Close, 2909.24$, Sentiment 0.021, Daily References 25
# 2021-09-01, Close, 2916.84$, Sentiment 0.121, Daily References 24
# 2021-09-02, Close, 2884.38$, Sentiment 0.033, Daily References 19
# 2021-09-03, Close, 2895.50$, Sentiment 0.042, Daily References 22
# 2021-09-03, BUY CREATE, 2895.50
# 2021-09-07, BUY EXECUTED, Price: 2894.99, Cost: 2894.99, Comm 2.89
# 2021-09-07, Close, 2910.38$, Sentiment 0.089, Daily References 13
# 2021-09-07, SELL CREATE, 2910.38
# 2021-09-08, SELL EXECUTED, Price: 2907.87, Cost: 2894.99, Comm 2.91
# 2021-09-08, OPERATION PROFIT, GROSS 12.88, NET 7.08
# 2021-09-08, Close, 2897.67$, Sentiment 0.013, Daily References 28
# 2021-09-09, Close, 2898.27$, Sentiment 0.059, Daily References 20
# 2021-09-09, BUY CREATE, 2898.27
# 2021-09-10, BUY EXECUTED, Price: 2908.87, Cost: 2908.87, Comm 2.91
# 2021-09-10, Close, 2838.42$, Sentiment 0.163, Daily References 17
# 2021-09-10, SELL CREATE, 2838.42
# 2021-09-21, SELL EXECUTED, Price: 2802.34, Cost: 2908.87, Comm 2.80
# 2021-09-21, OPERATION PROFIT, GROSS -106.53, NET -112.24
# 2021-09-21, Close, 2792.93$, Sentiment 0.003, Daily References 12
# 2021-09-22, Close, 2818.77$, Sentiment 0.069, Daily References 19
# 2021-09-23, Close, 2836.53$, Sentiment -0.104, Daily References 20
# 2021-09-24, Close, 2852.66$, Sentiment 0.029, Daily References 16
# 2021-09-27, Close, 2830.02$, Sentiment 0.001, Daily References 22
# 2021-09-29, Close, 2690.42$, Sentiment 0.015, Daily References 20
# 2021-09-30, Close, 2665.31$, Sentiment 0.078, Daily References 21
# 2021-10-01, Close, 2729.25$, Sentiment 0.078, Daily References 23
# 2021-10-04, Close, 2675.30$, Sentiment 0.071, Daily References 20
# 2021-10-06, Close, 2747.08$, Sentiment 0.154, Daily References 16
# 2021-10-07, Close, 2783.71$, Sentiment 0.032, Daily References 21
# 2021-10-08, Close, 2801.12$, Sentiment 0.027, Daily References 18
# 2021-10-08, BUY CREATE, 2801.12
# 2021-10-11, BUY EXECUTED, Price: 2796.00, Cost: 2796.00, Comm 2.80
# 2021-10-11, Close, 2776.95$, Sentiment 0.098, Daily References 12
# 2021-10-12, Close, 2734.26$, Sentiment 0.133, Daily References 22
# 2021-10-12, SELL CREATE, 2734.26
# 2021-10-15, SELL EXECUTED, Price: 2844.00, Cost: 2796.00, Comm 2.84
# 2021-10-15, OPERATION PROFIT, GROSS 48.00, NET 42.36
# 2021-10-15, Close, 2833.50$, Sentiment 0.219, Daily References 9
# 2021-10-18, Close, 2859.21$, Sentiment 0.107, Daily References 19
# 2021-10-18, BUY CREATE, 2859.21
# 2021-10-19, BUY EXECUTED, Price: 2865.83, Cost: 2865.83, Comm 2.87
# 2021-10-19, Close, 2876.44$, Sentiment 0.130, Daily References 39
# 2021-10-20, Close, 2848.30$, Sentiment 0.134, Daily References 24
# 2021-10-25, Close, 2775.46$, Sentiment 0.121, Daily References 15
# 2021-10-25, SELL CREATE, 2775.46
# 2021-10-26, SELL EXECUTED, Price: 2812.12, Cost: 2865.83, Comm 2.81
# 2021-10-26, OPERATION PROFIT, GROSS -53.71, NET -59.39
# 2021-10-26, Close, 2793.44$, Sentiment 0.152, Daily References 40
# 2021-10-27, Close, 2928.55$, Sentiment 0.054, Daily References 45
# 2021-10-27, BUY CREATE, 2928.55
# 2021-10-28, BUY EXECUTED, Price: 2945.98, Cost: 2945.98, Comm 2.95
# 2021-10-28, Close, 2922.58$, Sentiment 0.085, Daily References 5
# 2021-10-29, Close, 2965.41$, Sentiment 0.119, Daily References 32
# Final Portfolio Value: 100187.67
# <img src="data:image/png;base64,..." width="431.24999357387435">
